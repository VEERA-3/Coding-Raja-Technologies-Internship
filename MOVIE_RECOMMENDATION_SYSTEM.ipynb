# %% [markdown]
# # 1. Reading the Dataset with Pandas

# %%
import pandas as pd

movies = pd.read_csv("movies.csv")

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62423 rows x 3 columns]

# %% [markdown]
# # 2. Cleaning Movie Titles with Regex

# %%
import re

def title_cleaning(title):
    return re.sub("[^a-zA-Z0-9 ]","",title)

# %%
movies["title_cleaning"] = movies["title"].apply(title_cleaning)

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
#                          title_cleaning
# 0                        Toy Story 1995
# 1                          Jumanji 1995
# 2                 Grumpier Old Men 1995
# 3                Waiting to Exhale 1995
# 4      Father of the Bride Part II 1995
# ...                                 ...
# 62418                           We 2018
# 62419           Window of the Soul 2001
# 62420                    Bad Poems 2018
# 62421                 A Girl Thing 2001
# 62422       Women of Devils Island 1962
#
# [62423 rows x 4 columns]

# %% [markdown]
# # 3. Creating a TFIDF matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range=(1,2))

tfidf = vectorizer.fit_transform(movies["title_cleaning"])

# %% [markdown]
# # 4. Creating a SEARCH function

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def search(title):
    title = title_cleaning(title)
    query_vec = vectorizer.transform([title])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -8)[-8:]
    results = movies.iloc[indices][::-1]
    return results

# %% [markdown]
# # 5. Building an Interactive SEARCH BOX

# %%
import ipywidgets as widgets
from IPython.display import display

movie_input = widgets.Text(
    value ="Harry Potter",
    description = "Movie Title:",
    disabled = False
)
movie_list = widgets.Output()

def on_type(data):
    with movie_list:
        movie_list.clear_output()
        title = data["new"]
        if len(title) > 5:
            display(search(title))
            

movie_input.observe(on_type, names='value')

display(movie_input, movie_list)
# Out:
# Text(value='Harry Potter', description='Movie Title:')
# Output()

# %% [markdown]
# # 6. Reading in Movie Ratings Dataset

# %%
ratings = pd.read_csv("ratings.csv")

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
# [25000095 rows x 4 columns]

# %%
ratings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %% [markdown]
# # 7. Finding similar users who likes the same movie

# %%
movie_id = 1

# %%
similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] >= 5)]["userId"].unique()

# %%
similar_users
# Out:
# array([    36,     75,     86, ..., 162518, 162519, 162530], dtype=int64)

# %%
similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] > 4)]["movieId"]

# %%
similar_user_recs
# Out:
# 5101           1
# 5105          34
# 5111         110
# 5114         150
# 5127         260
#             ...
# 24998388    3706
# 24998389    3735
# 24998391    3763
# 24998392    4187
# 24998393    4321
# Name: movieId, Length: 912084, dtype: int64

# %%
similar_user_recs = similar_user_recs.value_counts() / len(similar_users)

similar_user_recs = similar_user_recs[similar_user_recs > .15]

# %%
similar_user_recs
# Out:
# 1        1.000000
# 318      0.414556
# 260      0.404561
# 356      0.347253
# 296      0.342663
# 1196     0.316304
# 1198     0.304605
# 593      0.304235
# 527      0.299052
# 2571     0.296609
# 3114     0.295498
# 1210     0.268695
# 50       0.262180
# 1270     0.254183
# 858      0.250555
# 364      0.249149
# 110      0.244484
# 589      0.241448
# 588      0.233674
# 608      0.231601
# 480      0.229898
# 4993     0.229083
# 1197     0.225233
# 2028     0.213239
# 4886     0.210647
# 150      0.205242
# 2959     0.205020
# 47       0.203613
# 5952     0.202577
# 7153     0.202058
# 2762     0.200281
# 595      0.198949
# 457      0.195469
# 2858     0.191619
# 1136     0.191322
# 6377     0.191026
# 1291     0.179698
# 4306     0.178958
# 8961     0.169554
# 1265     0.166963
# 1214     0.165038
# 1036     0.163335
# 58559    0.160743
# 1240     0.160743
# 1097     0.158448
# 34       0.158226
# 32       0.157856
# 541      0.155560
# 919      0.153858
# 1193     0.153191
# 1221     0.150748
# Name: movieId, dtype: float64

# %% [markdown]
# # 8. Finding how much all users like movies

# %%
all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]

# %%
all_users_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())

# %%
all_users_recs
# Out:
# 318      0.359607
# 296      0.299136
# 2571     0.256431
# 356      0.247218
# 593      0.237386
# 260      0.233496
# 2959     0.227727
# 527      0.226141
# 858      0.220727
# 50       0.210700
# 1196     0.197583
# 4993     0.197040
# 7153     0.181341
# 2858     0.176150
# 5952     0.174786
# 1198     0.172977
# 110      0.169045
# 58559    0.153910
# 47       0.151809
# 1210     0.151732
# 608      0.151628
# 589      0.141601
# 2028     0.138219
# 1221     0.133598
# 1        0.131065
# 1136     0.128706
# 1197     0.125387
# 1193     0.124830
# 2762     0.124308
# 541      0.120843
# 1270     0.120433
# 1214     0.106550
# 32       0.105388
# 480      0.104964
# 457      0.102758
# 1291     0.097156
# 150      0.095180
# 364      0.090121
# 1036     0.085354
# 1240     0.085215
# 1265     0.083942
# 4306     0.083517
# 6377     0.075939
# 4886     0.074408
# 8961     0.071931
# 588      0.070943
# 1097     0.064360
# 919      0.063998
# 595      0.063024
# 3114     0.056434
# 34       0.054883
# Name: movieId, dtype: float64

# %% [markdown]
# # 9. Creating a Recommendation Score

# %%
rec_percentages = pd.concat([similar_user_recs, all_users_recs], axis=1)
rec_percentages.columns = ["similar","all"]

# %%
rec_percentages
# Out:
#         similar       all
# 1      1.000000  0.131065
# 32     0.157856  0.105388
# 34     0.158226  0.054883
# 47     0.203613  0.151809
# 50     0.262180  0.210700
# 110    0.244484  0.169045
# 150    0.205242  0.095180
# 260    0.404561  0.233496
# 296    0.342663  0.299136
# 318    0.414556  0.359607
# 356    0.347253  0.247218
# 364    0.249149  0.090121
# 457    0.195469  0.102758
# 480    0.229898  0.104964
# 527    0.299052  0.226141
# 541    0.155560  0.120843
# 588    0.233674  0.070943
# 589    0.241448  0.141601
# 593    0.304235  0.237386
# 595    0.198949  0.063024
# 608    0.231601  0.151628
# 858    0.250555  0.220727
# 919    0.153858  0.063998
# 1036   0.163335  0.085354
# 1097   0.158448  0.064360
# 1136   0.191322  0.128706
# 1193   0.153191  0.124830
# 1196   0.316304  0.197583
# 1197   0.225233  0.125387
# 1198   0.304605  0.172977
# 1210   0.268695  0.151732
# 1214   0.165038  0.106550
# 1221   0.150748  0.133598
# 1240   0.160743  0.085215
# 1265   0.166963  0.083942
# 1270   0.254183  0.120433
# 1291   0.179698  0.097156
# 2028   0.213239  0.138219
# 2571   0.296609  0.256431
# 2762   0.200281  0.124308
# 2858   0.191619  0.176150
# 2959   0.205020  0.227727
# 3114   0.295498  0.056434
# 4306   0.178958  0.083517
# 4886   0.210647  0.074408
# 4993   0.229083  0.197040
# 5952   0.202577  0.174786
# 6377   0.191026  0.075939
# 7153   0.202058  0.181341
# 8961   0.169554  0.071931
# 58559  0.160743  0.153910

# %%
rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]

# %%
rec_percentages = rec_percentages.sort_values("score", ascending = False)

# %%
rec_percentages
# Out:
#         similar       all     score
# 1      1.000000  0.131065  7.629785
# 3114   0.295498  0.056434  5.236150
# 588    0.233674  0.070943  3.293828
# 595    0.198949  0.063024  3.156708
# 34     0.158226  0.054883  2.882995
# 4886   0.210647  0.074408  2.830961
# 364    0.249149  0.090121  2.764604
# 6377   0.191026  0.075939  2.515514
# 1097   0.158448  0.064360  2.461899
# 919    0.153858  0.063998  2.404089
# 8961   0.169554  0.071931  2.357177
# 480    0.229898  0.104964  2.190263
# 150    0.205242  0.095180  2.156363
# 4306   0.178958  0.083517  2.142763
# 1270   0.254183  0.120433  2.110587
# 1265   0.166963  0.083942  1.989035
# 1036   0.163335  0.085354  1.913611
# 457    0.195469  0.102758  1.902229
# 1240   0.160743  0.085215  1.886326
# 1291   0.179698  0.097156  1.849581
# 1197   0.225233  0.125387  1.796303
# 1210   0.268695  0.151732  1.770851
# 1198   0.304605  0.172977  1.760959
# 260    0.404561  0.233496  1.732625
# 589    0.241448  0.141601  1.705136
# 2762   0.200281  0.124308  1.611164
# 1196   0.316304  0.197583  1.600869
# 1214   0.165038  0.106550  1.548921
# 2028   0.213239  0.138219  1.542762
# 608    0.231601  0.151628  1.527428
# 32     0.157856  0.105388  1.497853
# 1136   0.191322  0.128706  1.486503
# 110    0.244484  0.169045  1.446262
# 356    0.347253  0.247218  1.404641
# 47     0.203613  0.151809  1.341247
# 527    0.299052  0.226141  1.322417
# 541    0.155560  0.120843  1.287293
# 593    0.304235  0.237386  1.281606
# 50     0.262180  0.210700  1.244330
# 1193   0.153191  0.124830  1.227195
# 4993   0.229083  0.197040  1.162625
# 5952   0.202577  0.174786  1.158997
# 2571   0.296609  0.256431  1.156679
# 318    0.414556  0.359607  1.152805
# 296    0.342663  0.299136  1.145506
# 858    0.250555  0.220727  1.135137
# 1221   0.150748  0.133598  1.128367
# 7153   0.202058  0.181341  1.114244
# 2858   0.191619  0.176150  1.087814
# 58559  0.160743  0.153910  1.044396
# 2959   0.205020  0.227727  0.900287

# %%
rec_percentages.head(10).merge(movies, left_index=True, right_on = "movieId")
# Out:
#        similar       all     score  movieId  \
# 0     1.000000  0.131065  7.629785        1
# 3021  0.295498  0.056434  5.236150     3114
# 580   0.233674  0.070943  3.293828      588
# 587   0.198949  0.063024  3.156708      595
# 33    0.158226  0.054883  2.882995       34
# 4780  0.210647  0.074408  2.830961     4886
# 359   0.249149  0.090121  2.764604      364
# 6258  0.191026  0.075939  2.515514     6377
# 1070  0.158448  0.064360  2.461899     1097
# 898   0.153858  0.063998  2.404089      919
#
#                                   title  \
# 0                      Toy Story (1995)
# 3021                 Toy Story 2 (1999)
# 580                      Aladdin (1992)
# 587         Beauty and the Beast (1991)
# 33                          Babe (1995)
# 4780              Monsters, Inc. (2001)
# 359               Lion King, The (1994)
# 6258                Finding Nemo (2003)
# 1070  E.T. the Extra-Terrestrial (1982)
# 898            Wizard of Oz, The (1939)
#
#                                                genres  \
# 0         Adventure|Animation|Children|Comedy|Fantasy
# 3021      Adventure|Animation|Children|Comedy|Fantasy
# 580       Adventure|Animation|Children|Comedy|Musical
# 587   Animation|Children|Fantasy|Musical|Romance|IMAX
# 33                                     Children|Drama
# 4780      Adventure|Animation|Children|Comedy|Fantasy
# 359   Adventure|Animation|Children|Drama|Musical|IMAX
# 6258              Adventure|Animation|Children|Comedy
# 1070                            Children|Drama|Sci-Fi
# 898                Adventure|Children|Fantasy|Musical
#
#                     title_cleaning
# 0                   Toy Story 1995
# 3021              Toy Story 2 1999
# 580                   Aladdin 1992
# 587      Beauty and the Beast 1991
# 33                       Babe 1995
# 4780             Monsters Inc 2001
# 359             Lion King The 1994
# 6258             Finding Nemo 2003
# 1070  ET the ExtraTerrestrial 1982
# 898          Wizard of Oz The 1939

# %% [markdown]
# # 10. Building a Recommendation Function

# %%
def find_similar_movies(movie_id):
    similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] > 4)]["userId"].unique()
    similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] > 4)]["movieId"]
    
    similar_user_recs = similar_user_recs.value_counts() / len(similar_users)
    similar_user_recs = similar_user_recs[similar_user_recs > .18]
    
    all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]
    all_user_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())
    
    rec_percentages = pd.concat([similar_user_recs, all_user_recs], axis=1)
    rec_percentages.columns = ["similar","all"]
    
    rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
    
    rec_percentages = rec_percentages.sort_values("score",ascending=False)
    return rec_percentages.head(15).merge(movies, left_index=True, right_on="movieId")[["score","title","genres"]]

# %% [markdown]
# # 11. Creating an Interactive Recommendation Widget

# %%
movie_name_input = widgets.Text(
    value = "Toy Story",
    description = "Movie Title:",
    disabled=False
)

recommendation_list = widgets.Output()

def on_type(data):
    with recommendation_list:
        recommendation_list.clear_output()
        title = data["new"]
        if len(title) > 5:
            results = search(title)
            movie_id = results.iloc[0]["movieId"]
            display(find_similar_movies(movie_id))
            
movie_name_input.observe(on_type, names="value")

display(movie_name_input, recommendation_list)
# Out:
# Text(value='Toy Story', description='Movie Title:')
# Output()
